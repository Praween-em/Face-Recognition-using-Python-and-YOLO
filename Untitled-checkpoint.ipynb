# %%
import os
from deepface import DeepFace
import matplotlib.pyplot as plt

#VGG-Face, Facenet, Facenet512,OpenFace, DeepFace, DeepID, Dlib, ArcFace and SFace 

img_1 = '52kbself.jpg'
img_2 = 'WIN_20231028_10_46_15_Pro.jpg'
img1 = DeepFace.detectFace(img_1)
img2 = DeepFace.detectFace(img_2)


model_name ='Facenet'
resp = DeepFace.verify(img1_path = img_1,img2_path = img_2,model_name=model_name)
plt.imshow(img1)
print(resp)
# Out:
# 24-02-17 13:21:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-17 13:21:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# {'verified': True, 'distance': 0.37476726329465104, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 140, 'y': 89, 'w': 261, 'h': 261}, 'img2': {'x': 127, 'y': 105, 'w': 154, 'h': 154}}, 'time': 0.84}

# %%
plt.imshow(img2)

# %%
model_name ='Facenet512'
resp = DeepFace.verify(img1_path = img_1,img2_path = img_2,model_name=model_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 model_name ='Facenet512'
# ----> 2 resp = DeepFace.verify(img1_path = img_1,img2_path = img_2,model_name=model_name)
#
# NameError: name 'DeepFace' is not defined
